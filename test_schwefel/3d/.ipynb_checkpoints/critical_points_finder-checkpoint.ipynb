# %%
import sys
import torch
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')

from critical_points.torch_critical_point_finder import find_critical_points_torch, save_critical_points_to_csv
from test_schwefel.schwefel_function_nnmodule import Schwefel3D, schwefel_loss_3d  # your existing module

# %%
# Set parameters
BOUNDS = (0.0, 1.0)
DIM = 3
ATTEMPTS = 64
MIN_DISTANCE = 0.01

# %%
# Run search
minima, maxima, saddles = find_critical_points_torch(
    model_class=Schwefel3D,
    loss_func=schwefel_loss_3d,
    bounds=BOUNDS,
    dimension=DIM,
    num_attempts=ATTEMPTS,
    min_distance=MIN_DISTANCE,
    device="cpu",
    lr=0.01,
    steps=400
)
# Out:
# Attempt 1/64: starting point [0.99751333 0.10436639 0.82297882]
# [0.99751333 0.10436639 0.82297882] Reject: False
# Attempt 2/64: starting point [0.22268048 0.73696758 0.44764793]
# [0.22268048 0.73696758 0.44764793] Reject: False
# Attempt 3/64: starting point [0.48094171 0.35632647 0.51044139]
# [0.48094171 0.35632647 0.51044139] Reject: False
# Attempt 4/64: starting point [0.73929411 0.98886296 0.13519257]
# [0.73929411 0.98886296 0.13519257] Reject: False
# Attempt 5/64: starting point [0.54678582 0.46132329 0.2819464 ]
# [0.54678582 0.46132329 0.2819464 ] Reject: False
# Attempt 6/64: starting point [0.30332528 0.8126126  0.9066477 ]
# [0.30332528 0.8126126  0.9066477 ] Reject: False
# Attempt 7/64: starting point [0.06142913 0.21714397 0.09447237]
# [0.06142913 0.21714397 0.09447237] Reject: False
# Attempt 8/64: starting point [0.78865527 0.56849041 0.71912985]
# [0.78865527 0.56849041 0.71912985] Reject: False
# Attempt 9/64: starting point [0.85367705 0.28965247 0.01324134]
# [0.85367705 0.28965247 0.01324134] Reject: False
# Attempt 10/64: starting point [0.11264099 0.92273732 0.63800784]
# [0.11264099 0.92273732 0.63800784] Reject: False
# Attempt 11/64: starting point [0.37026037 0.04555304 0.32570244]
# [0.37026037 0.04555304 0.32570244] Reject: False
# Attempt 12/64: starting point [0.5960386  0.67858052 0.95053957]
# [0.5960386  0.67858052 0.95053957] Reject: False
# Attempt 13/64: starting point [0.68038532 0.15051478 0.60108703]
# [0.68038532 0.15051478 0.60108703] Reject: False
# Attempt 14/64: starting point [0.40797647 0.50228943 0.22594293]
# [0.40797647 0.50228943 0.22594293] Reject: False
# Attempt 15/64: starting point [0.16574556 0.40246321 0.78860676]
# [0.16574556 0.40246321 0.78860676] Reject: False
# Attempt 16/64: starting point [0.92265052 0.7543028  0.41341505]
# [0.92265052 0.7543028  0.41341505] Reject: False
# Attempt 17/64: starting point [0.89698748 0.42159048 0.67982267]
# [0.89698748 0.42159048 0.67982267] Reject: False
# Attempt 18/64: starting point [0.14057008 0.80449604 0.05565502]
# [0.14057008 0.80449604 0.05565502] Reject: False
# Attempt 19/64: starting point [0.38237088 0.16556822 0.9923429 ]
# [0.38237088 0.16556822 0.9923429 ] Reject: False
# Attempt 20/64: starting point [0.65526681 0.54877499 0.36812762]
# [0.65526681 0.54877499 0.36812762] Reject: False
# Attempt 21/64: starting point [0.56652593 0.0283787  0.20525777]
# [0.56652593 0.0283787  0.20525777] Reject: False
# Attempt 22/64: starting point [0.34123671 0.63034026 0.58100071]
# [0.34123671 0.63034026 0.58100071] Reject: False
# Attempt 23/64: starting point [0.08307085 0.27655249 0.39271838]
# [0.08307085 0.27655249 0.39271838] Reject: False
# Attempt 24/64: starting point [0.82459638 0.87820515 0.76853195]
# [0.82459638 0.87820515 0.76853195] Reject: False
# Attempt 25/64: starting point [0.75182176 0.23236382 0.49911014]
# [0.75182176 0.23236382 0.49911014] Reject: False
# Attempt 26/64: starting point [0.02410853 0.61477808 0.87478811]
# [0.02410853 0.61477808 0.87478811] Reject: False
# Attempt 27/64: starting point [0.26642718 0.48028223 0.18663564]
# [0.26642718 0.48028223 0.18663564] Reject: False
# Attempt 28/64: starting point [0.50940015 0.86300564 0.5622698 ]
# [0.50940015 0.86300564 0.5622698 ] Reject: False
# Attempt 29/64: starting point [0.70630332 0.34305912 0.89560989]
# [0.70630332 0.34305912 0.89560989] Reject: False
# Attempt 30/64: starting point [0.44746145 0.94452773 0.27125568]
# [0.44746145 0.94452773 0.27125568] Reject: False
# Attempt 31/64: starting point [0.18975431 0.08736132 0.70807292]
# [0.18975431 0.08736132 0.70807292] Reject: False
# Attempt 32/64: starting point [0.96409816 0.68852847 0.08380078]
# [0.96409816 0.68852847 0.08380078] Reject: False
# Attempt 33/64: starting point [0.93912561 0.36948579 0.33710597]
# [0.93912561 0.36948579 0.33710597] Reject: False
# Attempt 34/64: starting point [0.21176286 0.97083614 0.96281625]
# [0.21176286 0.97083614 0.96281625] Reject: False
# Attempt 35/64: starting point [0.4537582  0.12148151 0.02463384]
# [0.4537582  0.12148151 0.02463384] Reject: False
# Attempt 36/64: starting point [0.69711121 0.72276692 0.6502965 ]
# [0.69711121 0.72276692 0.6502965 ] Reject: False
# Attempt 37/64: starting point [0.51876297 0.19616841 0.80004201]
# [0.51876297 0.19616841 0.80004201] Reject: False
# Attempt 38/64: starting point [0.26002839 0.57870856 0.42566288]
# [0.26002839 0.57870856 0.42566288] Reject: False
# Attempt 39/64: starting point [0.00217152 0.45202449 0.61251029]
# [0.00217152 0.45202449 0.61251029] Reject: False
# Attempt 40/64: starting point [0.77665413 0.83462202 0.2382018 ]
# [0.77665413 0.83462202 0.2382018 ] Reject: False
# Attempt 41/64: starting point [0.83491644 0.05480895 0.5293259 ]
# [0.83491644 0.05480895 0.5293259 ] Reject: False
# Attempt 42/64: starting point [0.07766029 0.65664464 0.15512594]
# [0.07766029 0.65664464 0.15512594] Reject: False
# Attempt 43/64: starting point [0.32029557 0.31066912 0.84184373]
# [0.32029557 0.31066912 0.84184373] Reject: False
# Attempt 44/64: starting point [0.59232318 0.91244767 0.46759996]
# [0.59232318 0.91244767 0.46759996] Reject: False
# Attempt 45/64: starting point [0.62930648 0.38539866 0.1133266 ]
# [0.62930648 0.38539866 0.1133266 ] Reject: False
# Attempt 46/64: starting point [0.40342169 0.76842248 0.73909445]
# [0.40342169 0.76842248 0.73909445] Reject: False
# Attempt 47/64: starting point [0.14590148 0.13730692 0.30078197]
# [0.14590148 0.13730692 0.30078197] Reject: False
# Attempt 48/64: starting point [0.88679997 0.52039544 0.92663191]
# [0.88679997 0.52039544 0.92663191] Reject: False
# Attempt 49/64: starting point [0.91637379 0.18670685 0.16764771]
# [0.91637379 0.18670685 0.16764771] Reject: False
# Attempt 50/64: starting point [0.17498631 0.53836324 0.54243889]
# [0.17498631 0.53836324 0.54243889] Reject: False
# Attempt 51/64: starting point [0.43293091 0.43072429 0.4801026 ]
# [0.43293091 0.43072429 0.4801026 ] Reject: False
# Attempt 52/64: starting point [0.65832623 0.78268213 0.85497585]
# [0.65832623 0.78268213 0.85497585] Reject: False
# Attempt 53/64: starting point [0.61792507 0.26322246 0.68911623]
# [0.61792507 0.26322246 0.68911623] Reject: False
# Attempt 54/64: starting point [0.34540989 0.8964332  0.06393959]
# [0.34540989 0.8964332  0.06393959] Reject: False
# Attempt 55/64: starting point [0.10332681 0.01143619 0.87663455]
# [0.10332681 0.01143619 0.87663455] Reject: False
# Attempt 56/64: starting point [0.86009587 0.64433778 0.2514141 ]
# [0.86009587 0.64433778 0.2514141 ] Reject: False
# Attempt 57/64: starting point [0.809584   0.4975194  0.98107151]
# [0.809584   0.4975194  0.98107151] Reject: False
# Attempt 58/64: starting point [0.03559087 0.84868282 0.35571594]
# [0.03559087 0.84868282 0.35571594] Reject: False
# Attempt 59/64: starting point [0.29301571 0.24540097 0.66854026]
# [0.29301571 0.24540097 0.66854026] Reject: False
# Attempt 60/64: starting point [0.55223929 0.5968733  0.04325532]
# [0.55223929 0.5968733  0.04325532] Reject: False
# Attempt 61/64: starting point [0.73400562 0.07794042 0.38141814]
# [0.73400562 0.07794042 0.38141814] Reject: False
# Attempt 62/64: starting point [0.4911397  0.71065987 0.75615198]
# [0.4911397  0.71065987 0.75615198] Reject: False
# Attempt 63/64: starting point [0.2485998  0.32220555 0.19394555]
# [0.2485998  0.32220555 0.19394555] Reject: False
# Attempt 64/64: starting point [0.97645012 0.95462378 0.56863176]
# [0.97645012 0.95462378 0.56863176] Reject: False
# saddle [0.99751333 0.10436639 0.82297882]
# saddle [0.22268048 0.73696758 0.44764793]
# saddle [0.48094171 0.35632647 0.51044139]
# saddle [0.73929411 0.98886296 0.13519257]
# saddle [0.54678582 0.46132329 0.2819464 ]
# minimum [0.30332528 0.8126126  0.9066477 ]
# saddle [0.06142913 0.21714397 0.09447237]
# saddle [0.78865527 0.56849041 0.71912985]
# minimum [0.85367705 0.28965247 0.01324134]
# saddle [0.11264099 0.92273732 0.63800784]
# minimum [0.37026037 0.04555304 0.32570244]
# saddle [0.5960386  0.67858052 0.95053957]
# maximum [0.68038532 0.15051478 0.60108703]
# saddle [0.40797647 0.50228943 0.22594293]
# saddle [0.16574556 0.40246321 0.78860676]
# minimum [0.92265052 0.7543028  0.41341505]
# saddle [0.89698748 0.42159048 0.67982267]
# saddle [0.14057008 0.80449604 0.05565502]
# saddle [0.38237088 0.16556822 0.9923429 ]
# saddle [0.65526681 0.54877499 0.36812762]
# saddle [0.56652593 0.0283787  0.20525777]
# saddle [0.34123671 0.63034026 0.58100071]
# minimum [0.08307085 0.27655249 0.39271838]
# minimum [0.82459638 0.87820515 0.76853195]
# saddle [0.75182176 0.23236382 0.49911014]
# saddle [0.02410853 0.61477808 0.87478811]
# saddle [0.26642718 0.48028223 0.18663564]
# saddle [0.50940015 0.86300564 0.5622698 ]
# minimum [0.70630332 0.34305912 0.89560989]
# minimum [0.44746145 0.94452773 0.27125568]
# saddle [0.18975431 0.08736132 0.70807292]
# saddle [0.96409816 0.68852847 0.08380078]
# minimum [0.93912561 0.36948579 0.33710597]
# saddle [0.21176286 0.97083614 0.96281625]
# saddle [0.4537582  0.12148151 0.02463384]
# saddle [0.69711121 0.72276692 0.6502965 ]
# saddle [0.51876297 0.19616841 0.80004201]
# saddle [0.26002839 0.57870856 0.42566288]
# saddle [0.00217152 0.45202449 0.61251029]
# saddle [0.77665413 0.83462202 0.2382018 ]
# saddle [0.83491644 0.05480895 0.5293259 ]
# saddle [0.07766029 0.65664464 0.15512594]
# minimum [0.32029557 0.31066912 0.84184373]
# saddle [0.59232318 0.91244767 0.46759996]
# saddle [0.62930648 0.38539866 0.1133266 ]
# minimum [0.40342169 0.76842248 0.73909445]
# saddle [0.14590148 0.13730692 0.30078197]
# saddle [0.88679997 0.52039544 0.92663191]
# saddle [0.91637379 0.18670685 0.16764771]
# maximum [0.17498631 0.53836324 0.54243889]
# saddle [0.43293091 0.43072429 0.4801026 ]
# saddle [0.65832623 0.78268213 0.85497585]
# saddle [0.61792507 0.26322246 0.68911623]
# minimum [0.34540989 0.8964332  0.06393959]
# saddle [0.10332681 0.01143619 0.87663455]
# saddle [0.86009587 0.64433778 0.2514141 ]
# saddle [0.809584   0.4975194  0.98107151]
# minimum [0.03559087 0.84868282 0.35571594]
# saddle [0.29301571 0.24540097 0.66854026]
# saddle [0.55223929 0.5968733  0.04325532]
# minimum [0.73400562 0.07794042 0.38141814]
# saddle [0.4911397  0.71065987 0.75615198]
# saddle [0.2485998  0.32220555 0.19394555]
# saddle [0.97645012 0.95462378 0.56863176]

# %%
# Save to CSV
results_df = save_critical_points_to_csv(minima, saddles, dimension=DIM, filename="critical_points_schwefel_torch3D.csv")
display(results_df.head())
# Out:
# Saved critical_points_schwefel_torch3D.csv
#          x1        x2        x3   f_value     type  index
# 0  0.303325  0.812613  0.906648  0.421170  minimum      0
# 1  0.853677  0.289652  0.013241  0.670719  minimum      0
# 2  0.370260  0.045553  0.325702  0.820242  minimum      0
# 3  0.922651  0.754303  0.413415  0.685066  minimum      0
# 4  0.083071  0.276552  0.392718  1.008514  minimum      0
