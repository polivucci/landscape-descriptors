# %%
import sys
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')
from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function, plot_full_connectivity_tree_style

from critical_points.torch_critical_point_finder import find_critical_points_torch, save_critical_points_to_csv
from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss, schwefel2D_numpy 

import matplotlib.pyplot as plt
import pandas as pd

# %%
model_builder = lambda p: Schwefel2D(*p)

# %%
# Set parameters
BOUNDS = {'x1': (0.0, 1.0), 'x2': (0.0, 1.0)}
DIM = 2
ATTEMPTS = 8
MIN_DISTANCE = 0.01

# %%
try:
    resume_df = pd.read_csv("critical_points_schwefel_torch.csv", index_col=0)
    display(resume_df)
except FileNotFoundError:
    resume_df = None

# %%
# Run search
minima, maxima, saddles = find_critical_points_torch(
    model_builder=model_builder,
    loss_func=schwefel_loss,
    minima_only=False,
    input = [],             # placeholder model input for compatibility (Schwefel model has no model input)
    bounds=BOUNDS,
    dimension=DIM,
    num_attempts=ATTEMPTS,
    min_distance=MIN_DISTANCE,
    device="cpu",
    lr=5e-2,
    max_iter=5_000,
    resume_df=resume_df,  # 👈 here!
    seed=1101
)
# Out:
# __________________________________________________________________________________________
# Attempt 1/8:
# Starting point: [0.25317813 0.88321528]
# learning rate 0.05
# Converged after 256 iterations.
# Arrival point: [0.56116667 0.8243751 ]
# check grad: tensor([-7.8352e-06,  5.6196e-06], grad_fn=<CatBackward0>)
# tensor(9.6421e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.64e-06 < 1e-05
# New minimum found at [0.56116667 0.8243751 ] with value 0.300545
# Type: saddle
#
# __________________________________________________________________________________________
# Attempt 2/8:
# Starting point: [0.76250551 0.35659261]
# learning rate 0.05
# Converged after 246 iterations.
# Arrival point: [0.82437482 0.3418095 ]
# check grad: tensor([-9.4134e-06,  2.5218e-06], grad_fn=<CatBackward0>)
# tensor(9.7453e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.75e-06 < 1e-05
# New minimum found at [0.82437482 0.3418095 ] with value -0.201843
# Type: minimum
#
# __________________________________________________________________________________________
# Attempt 3/8:
# Starting point: [0.65636731 0.73049768]
# learning rate 0.05
# Converged after 258 iterations.
# Arrival point: [0.56116665 0.82437487]
# check grad: tensor([-6.8369e-06, -6.7252e-06], grad_fn=<CatBackward0>)
# tensor(9.5901e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.59e-06 < 1e-05
# Point [0.56116665 0.82437487] is too close to existing minimum at [0.56116667 0.8243751 ] (distance 0.000000 < 0.01)
# Minimum at [0.56116667 0.8243751 ] has now been found 2 times.
# Point [0.56116665 0.82437487] is too close to existing minimum. Rejecting.
#
# __________________________________________________________________________________________
# Attempt 4/8:
# Starting point: [0.17145488 0.00906608]
# learning rate 0.05
# Converged after 229 iterations.
# Arrival point: [0.1662875  0.03455065]
# check grad: tensor([-2.1426e-06, -9.2998e-06], grad_fn=<CatBackward0>)
# tensor(9.5434e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.54e-06 < 1e-05
# New minimum found at [0.1662875  0.03455065] with value 0.478224
# Type: saddle
#
# __________________________________________________________________________________________
# Attempt 5/8:
# Starting point: [0.07226059 0.52750919]
# learning rate 0.05
# Converged after 242 iterations.
# Arrival point: [0.03455094 0.5611664 ]
# check grad: tensor([7.1232e-06, 6.6833e-06], grad_fn=<CatBackward0>)
# tensor(9.7676e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.77e-06 < 1e-05
# New minimum found at [0.03455094 0.5611664 ] with value 0.655892
# Type: saddle
#
# __________________________________________________________________________________________
# Attempt 6/8:
# Starting point: [0.56879307 0.2435468 ]
# learning rate 0.05
# Converged after 244 iterations.
# Arrival point: [0.56116655 0.16628764]
# check grad: tensor([-1.4368e-06, -9.8092e-06], grad_fn=<CatBackward0>)
# tensor(9.9139e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.91e-06 < 1e-05
# New minimum found at [0.56116655 0.16628764] with value 0.842404
# Type: maximum
#
# __________________________________________________________________________________________
# Attempt 7/8:
# Starting point: [0.97913096 0.86745211]
# learning rate 0.05
# Out of bounds at 0 iterations.
# Arrival point: [1.18339416 0.86515326]
# check grad: tensor([4.9922, 2.1447], grad_fn=<CatBackward0>)
# tensor(5.4334, grad_fn=<LinalgVectorNormBackward0>)
#
# __________________________________________________________________________________________
# Attempt 8/8:
# Starting point: [0.47380949 0.40335975]
# learning rate 0.05
# Converged after 253 iterations.
# Arrival point: [0.56116638 0.34180957]
# check grad: tensor([7.6075e-06, 6.4046e-06], grad_fn=<CatBackward0>)
# tensor(9.9445e-06, grad_fn=<LinalgVectorNormBackward0>)
# Converged to critical point with ||grad||=9.94e-06 < 1e-05
# New minimum found at [0.56116638 0.34180957] with value 0.517684
# Type: saddle

# %%
# Save to CSV
results_df = save_critical_points_to_csv(minima, maxima, saddles, dimension=DIM, filename="critical_points_schwefel_torch.csv")

results_df = pd.concat((resume_df,results_df), ignore_index=True)

display(results_df)
# Out:
# Saved critical_points_schwefel_torch.csv
#          x1        x2   f_value     type  index
# 0  0.824375  0.341809 -0.201843  minimum      0
# 1  0.561167  0.166288  0.842404  maximum      2
# 2  0.561167  0.824375  0.300545   saddle      1
# 3  0.166287  0.034551  0.478224   saddle      1
# 4  0.034551  0.561166  0.655892   saddle      1
# 5  0.561166  0.341810  0.517684   saddle      1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_attempt_basins_2d(bounds=((0,1),(0,1)), res=250, loss_fn=schwefel_loss, finder=finder, minima_df=resume_df)
#
# NameError: name 'finder' is not defined

# %%
fig2 = plt.figure(figsize=(5,4), dpi=160)
fig2 = plot_results_with_paths(func=schwefel2D_numpy,  
                                critical_points_df=results_df,
                                connectivity_df=None, 
                                bounds=(0, 1),
                                res=200,
                                fig=fig2
)
plt.xlim(*BOUNDS['x1'])
plt.ylim(*BOUNDS['x2'])
fig2.show()
# fig2.savefig("plots/landscape_paths.png")  # Optional
# Out:
# /var/folders/87/h8fnyth55477f11hgmy38l4h0000gn/T/ipykernel_58579/2176601272.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
