# %%
import sys
import torch
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')
from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function

from critical_points.torch_critical_point_finder import find_critical_points_torch, save_critical_points_to_csv
from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss_2d, schwefel2D_numpy # your existing module

import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set parameters
BOUNDS = (0.0, 1.0)
DIM = 2
ATTEMPTS = 64
MIN_DISTANCE = 0.01

# %%
# Run search
minima, maxima, saddles = find_critical_points_torch(
    model_class=Schwefel2D,
    loss_func=schwefel_loss_2d,
    bounds=BOUNDS,
    dimension=DIM,
    num_attempts=ATTEMPTS,
    min_distance=MIN_DISTANCE,
    device="cpu",
    lr=0.01,
    steps=400
)
# Out:
# Attempt 1/64: starting point [0.99751333 0.10436639]
# [0.99751333 0.10436639] Reject: False
# Attempt 2/64: starting point [0.11113402 0.78797661]
# [0.11113402 0.78797661] Reject: False
# Attempt 3/64: starting point [0.36518787 0.35327499]
# [0.36518787 0.35327499] Reject: False
# Attempt 4/64: starting point [0.74344997 0.53709689]
# [0.74344997 0.53709689] Reject: False
# Attempt 5/64: starting point [0.58225436 0.48780095]
# [0.58225436 0.48780095] Reject: False
# Attempt 6/64: starting point [0.46143819 0.68724926]
# [0.46143819 0.68724926] Reject: False
# Attempt 7/64: starting point [0.21556688 0.23497762]
# [0.21556688 0.23497762] Reject: False
# Attempt 8/64: starting point [0.82814283 0.93421048]
# [0.82814283 0.93421048] Reject: False
# Attempt 9/64: starting point [0.7723202  0.26171045]
# [0.7723202  0.26171045] Reject: False
# Attempt 10/64: starting point [0.15076505 0.57007411]
# [0.15076505 0.57007411] Reject: False
# Attempt 11/64: starting point [0.40465152 0.00867554]
# [0.40465152 0.00867554] Reject: False
# Attempt 12/64: starting point [0.51845473 0.81725477]
# [0.51845473 0.81725477] Reject: False
# Attempt 13/64: starting point [0.68709287 0.14319136]
# [0.68709287 0.14319136] Reject: False
# Attempt 14/64: starting point [0.29997435 0.96739417]
# [0.29997435 0.96739417] Reject: False
# Attempt 15/64: starting point [0.05378212 0.39233088]
# [0.05378212 0.39233088] Reject: False
# Attempt 16/64: starting point [0.93327172 0.7163219 ]
# [0.93327172 0.7163219 ] Reject: False
# Attempt 17/64: starting point [0.8989859 0.4300926]
# [0.8989859 0.4300926] Reject: False
# Attempt 18/64: starting point [0.01974104 0.73861075]
# [0.01974104 0.73861075] Reject: False
# Attempt 19/64: starting point [0.26565621 0.18306679]
# [0.26565621 0.18306679] Reject: False
# Attempt 20/64: starting point [0.65301923 0.99149153]
# [0.65301923 0.99149153] Reject: False
# Attempt 21/64: starting point [0.54859014 0.03243685]
# [0.54859014 0.03243685] Reject: False
# Attempt 22/64: starting point [0.43503047 0.85648898]
# [0.43503047 0.85648898] Reject: False
# Attempt 23/64: starting point [0.18093276 0.28335879]
# [0.18093276 0.28335879] Reject: False
# Attempt 24/64: starting point [0.80273169 0.6075005 ]
# [0.80273169 0.6075005 ] Reject: False
# Attempt 25/64: starting point [0.8624305  0.21219213]
# [0.8624305  0.21219213] Reject: False
# Attempt 26/64: starting point [0.24961005 0.89595303]
# [0.24961005 0.89595303] Reject: False
# Attempt 27/64: starting point [0.4957546  0.46322266]
# [0.4957546  0.46322266] Reject: False
# Attempt 28/64: starting point [0.61632603 0.64689387]
# [0.61632603 0.64689387] Reject: False
# Attempt 29/64: starting point [0.71331271 0.31258379]
# [0.71331271 0.31258379] Reject: False
# Attempt 30/64: starting point [0.33480682 0.5118776 ]
# [0.33480682 0.5118776 ] Reject: False
# Attempt 31/64: starting point [0.08096804 0.0654682 ]
# [0.08096804 0.0654682 ] Reject: False
# Attempt 32/64: starting point [0.9671038  0.76485555]
# [0.9671038  0.76485555] Reject: False
# Attempt 33/64: starting point [0.94053318 0.36192981]
# [0.94053318 0.36192981] Reject: False
# Attempt 34/64: starting point [0.07776686 0.5611645 ]
# [0.07776686 0.5611645 ] Reject: False
# Attempt 35/64: starting point [0.32384034 0.11084873]
# [0.32384034 0.11084873] Reject: False
# Attempt 36/64: starting point [0.69448068 0.8102952 ]
# [0.69448068 0.8102952 ] Reject: False
# Attempt 37/64: starting point [0.60384178 0.23022712]
# [0.60384178 0.23022712] Reject: False
# Attempt 38/64: starting point [0.47551065 0.91405097]
# [0.47551065 0.91405097] Reject: False
# Attempt 39/64: starting point [0.2215064  0.47741422]
# [0.2215064  0.47741422] Reject: False
# Attempt 40/64: starting point [0.85783266 0.66102249]
# [0.85783266 0.66102249] Reject: False
# Attempt 41/64: starting point [0.78974951 0.01928491]
# [0.78974951 0.01928491] Reject: False
# Attempt 42/64: starting point [0.16020638 0.8432741 ]
# [0.16020638 0.8432741 ] Reject: False
# Attempt 43/64: starting point [0.4064482 0.2662373]
# [0.4064482 0.2662373] Reject: False
# Attempt 44/64: starting point [0.54349817 0.59044195]
# [0.54349817 0.59044195] Reject: False
# Attempt 45/64: starting point [0.62693129 0.38562963]
# [0.62693129 0.38562963] Reject: False
# Attempt 46/64: starting point [0.26295272 0.69420691]
# [0.26295272 0.69420691] Reject: False
# Attempt 47/64: starting point [0.00926844 0.13475634]
# [0.00926844 0.13475634] Reject: False
# Attempt 48/64: starting point [0.88063273 0.94312195]
# [0.88063273 0.94312195] Reject: False
# Attempt 49/64: starting point [0.91296674 0.1564047 ]
# [0.91296674 0.1564047 ] Reject: False
# Attempt 50/64: starting point [0.0413589  0.98054838]
# [0.0413589  0.98054838] Reject: False
# Attempt 51/64: starting point [0.29531547 0.40939099]
# [0.29531547 0.40939099] Reject: False
# Attempt 52/64: starting point [0.65905026 0.73344113]
# [0.65905026 0.73344113] Reject: False
# Attempt 53/64: starting point [0.51531457 0.30611276]
# [0.51531457 0.30611276] Reject: False
# Attempt 54/64: starting point [0.37801986 0.61453935]
# [0.37801986 0.61453935] Reject: False
# Attempt 55/64: starting point [0.13199406 0.05704668]
# [0.13199406 0.05704668] Reject: False
# Attempt 56/64: starting point [0.76129269 0.86556297]
# [0.76129269 0.86556297] Reject: False
# Attempt 57/64: starting point [0.82550037 0.43851607]
# [0.82550037 0.43851607] Reject: False
# Attempt 58/64: starting point [0.1894179  0.63790144]
# [0.1894179  0.63790144] Reject: False
# Attempt 59/64: starting point [0.44314606 0.18953593]
# [0.44314606 0.18953593] Reject: False
# Attempt 60/64: starting point [0.57172073 0.88883173]
# [0.57172073 0.88883173] Reject: False
# Attempt 61/64: starting point [0.72266255 0.08627047]
# [0.72266255 0.08627047] Reject: False
# Attempt 62/64: starting point [0.35226671 0.76993983]
# [0.35226671 0.76993983] Reject: False
# Attempt 63/64: starting point [0.10598102 0.33914433]
# [0.10598102 0.33914433] Reject: False
# Attempt 64/64: starting point [0.96899208 0.5229071 ]
# [0.96899208 0.5229071 ] Reject: False
# maximum [0.99751333 0.10436639]
# saddle [0.11113402 0.78797661]
# minimum [0.36518787 0.35327499]
# saddle [0.74344997 0.53709689]
# maximum [0.58225436 0.48780095]
# maximum [0.46143819 0.68724926]
# maximum [0.21556688 0.23497762]
# minimum [0.82814283 0.93421048]
# minimum [0.7723202  0.26171045]
# maximum [0.15076505 0.57007411]
# minimum [0.40465152 0.00867554]
# saddle [0.51845473 0.81725477]
# maximum [0.68709287 0.14319136]
# minimum [0.29997435 0.96739417]
# minimum [0.05378212 0.39233088]
# minimum [0.93327172 0.7163219 ]
# minimum [0.8989859 0.4300926]
# minimum [0.01974104 0.73861075]
# saddle [0.26565621 0.18306679]
# maximum [0.65301923 0.99149153]
# saddle [0.54859014 0.03243685]
# minimum [0.43503047 0.85648898]
# saddle [0.18093276 0.28335879]
# saddle [0.80273169 0.6075005 ]
# saddle [0.8624305  0.21219213]
# saddle [0.24961005 0.89595303]
# maximum [0.4957546  0.46322266]
# maximum [0.61632603 0.64689387]
# minimum [0.71331271 0.31258379]
# saddle [0.33480682 0.5118776 ]
# minimum [0.08096804 0.0654682 ]
# minimum [0.9671038  0.76485555]
# minimum [0.94053318 0.36192981]
# saddle [0.07776686 0.5611645 ]
# saddle [0.32384034 0.11084873]
# minimum [0.69448068 0.8102952 ]
# maximum [0.60384178 0.23022712]
# saddle [0.47551065 0.91405097]
# maximum [0.2215064  0.47741422]
# saddle [0.85783266 0.66102249]
# minimum [0.78974951 0.01928491]
# saddle [0.16020638 0.8432741 ]
# minimum [0.4064482 0.2662373]
# maximum [0.54349817 0.59044195]
# saddle [0.62693129 0.38562963]
# minimum [0.26295272 0.69420691]
# saddle [0.00926844 0.13475634]
# minimum [0.88063273 0.94312195]
# saddle [0.91296674 0.1564047 ]
# saddle [0.0413589  0.98054838]
# minimum [0.29531547 0.40939099]
# saddle [0.65905026 0.73344113]
# saddle [0.51531457 0.30611276]
# saddle [0.37801986 0.61453935]
# saddle [0.13199406 0.05704668]
# minimum [0.76129269 0.86556297]
# minimum [0.82550037 0.43851607]
# maximum [0.1894179  0.63790144]
# saddle [0.44314606 0.18953593]
# saddle [0.57172073 0.88883173]
# minimum [0.72266255 0.08627047]
# minimum [0.35226671 0.76993983]
# saddle [0.10598102 0.33914433]
# saddle [0.96899208 0.5229071 ]

# %%
# Save to CSV
results_df = save_critical_points_to_csv(minima, saddles, dimension=DIM, filename="critical_points_schwefel_torch2D.csv")
display(results_df.head())
# Out:
# Saved critical_points_schwefel_torch2D.csv
#          x1        x2   f_value     type  index
# 0  0.365188  0.353275  0.451732  minimum      0
# 1  0.828143  0.934210  0.279183  minimum      0
# 2  0.772320  0.261710  0.422488  minimum      0
# 3  0.404652  0.008676  0.685169  minimum      0
# 4  0.299974  0.967394  0.697854  minimum      0

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 fig2 = plt.figure(figsize=(5,5), dpi=160)
# ----> 2 fig2 = plot_results_with_paths(func=schwefel2D_numpy,
#       3                                 critical_points_csv="./critical_points_schwefel_torch2D.csv",
#       4                                 saddle_to_minima_csv="results/dummy.csv",
#       5                                 bounds=(0, 1),
#       6                                 res=200,
#       7                                 fig=fig2
#       8 )
#       9 fig2.show()
#      10 fig2.savefig("plots/landscape_paths.png")  # Optional
#
# File ~/Documents/Documents/python-project/Hiwi task/landscape-descriptors/test_schwefel/2d/../../connectivity/plot_results.py:72, in plot_results_with_paths(func, critical_points_csv, saddle_to_minima_csv, bounds, res, fig)
#      69     ax.text(point[0] + 0.015, point[1] + 0.015, f"M{i}", fontsize=8, color=text_color)
#      71 minima_coords = np.array(minima_coords)
# ---> 72 ax.scatter(minima_coords[:, 0], minima_coords[:, 1],
#      73     c=minima_color, s=50, edgecolor=edge_color, linewidth=1.5, zorder=10, label='Minima')
#      75 # Plot saddle points with labels
#      76 for i in saddle_indices:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
