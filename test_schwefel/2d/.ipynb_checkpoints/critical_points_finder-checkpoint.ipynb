# %%
import sys
import torch
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')
from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function

from critical_points.torch_critical_point_finder import find_critical_points_torch, save_critical_points_to_csv
from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss, schwefel2D_numpy # your existing module

import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set parameters
BOUNDS = (0.0, 1.0)
DIM = 2
ATTEMPTS = 64
MIN_DISTANCE = 0.01

# %%
# Run search
minima, maxima, saddles = find_critical_points_torch(
    model_class=Schwefel2D,
    loss_func=schwefel_loss,
    input = [],             # placeholder model input for compatibility (Schwefel model has no model input)
    bounds=BOUNDS,
    dimension=DIM,
    num_attempts=ATTEMPTS,
    min_distance=MIN_DISTANCE,
    device="cpu",
    lr=1e-3,
    steps=1400
)
# Out:
# Attempt 1/64: starting point [0.99751333 0.10436639]
# [0.824376   0.03455278] Reject: False
# Attempt 2/64: starting point [0.11113402 0.78797661]
# [0.03455331 0.82437526] Reject: False
# Attempt 3/64: starting point [0.36518787 0.35327499]
# [0.34181224 0.34181104] Reject: False
# Attempt 4/64: starting point [0.74344997 0.53709689]
# [0.8243765  0.34181097] Reject: False
# Attempt 5/64: starting point [0.58225436 0.48780095]
# [0.82437503 0.34180722] Reject: True
# Attempt 6/64: starting point [0.46143819 0.68724926]
# [0.34181521 0.82436705] Reject: False
# Attempt 7/64: starting point [0.21556688 0.23497762]
# [0.3418075 0.3418102] Reject: True
# Attempt 8/64: starting point [0.82814283 0.93421048]
# [0.82437499 0.82437655] Reject: False
# Attempt 9/64: starting point [0.7723202  0.26171045]
# [0.82437413 0.34180586] Reject: True
# Attempt 10/64: starting point [0.15076505 0.57007411]
# [-0.16861631  0.82437262] Reject: True
# Rejected: Out of bounds -> [-0.1686163087043253, 0.8243726207661358]
# Attempt 11/64: starting point [0.40465152 0.00867554]
# [0.3418122  0.03455258] Reject: False
# Attempt 12/64: starting point [0.51845473 0.81725477]
# [0.34180946 0.82437655] Reject: True
# Attempt 13/64: starting point [0.68709287 0.14319136]
# [0.82437461 0.0345543 ] Reject: True
# Attempt 14/64: starting point [0.29997435 0.96739417]
# [0.34181005 0.82437653] Reject: True
# Attempt 15/64: starting point [0.05378212 0.39233088]
# [0.03455387 0.34181216] Reject: False
# Attempt 16/64: starting point [0.93327172 0.7163219 ]
# [0.82437784 0.82437216] Reject: True
# Attempt 17/64: starting point [0.8989859 0.4300926]
# [0.82437627 0.34181223] Reject: True
# Attempt 18/64: starting point [0.01974104 0.73861075]
# [0.03455163 0.82437082] Reject: True
# Attempt 19/64: starting point [0.26565621 0.18306679]
# [0.34181231 0.34180979] Reject: True
# Attempt 20/64: starting point [0.65301923 0.99149153]
# [0.82437089 0.82437444] Reject: True
# Attempt 21/64: starting point [0.54859014 0.03243685]
# [0.34181009 0.03455329] Reject: True
# Attempt 22/64: starting point [0.43503047 0.85648898]
# [0.34181231 0.824375  ] Reject: True
# Attempt 23/64: starting point [0.18093276 0.28335879]
# [0.34181186 0.34181194] Reject: True
# Attempt 24/64: starting point [0.80273169 0.6075005 ]
# [0.82437655 0.82437532] Reject: True
# Attempt 25/64: starting point [0.8624305  0.21219213]
# [0.82437133 0.34180404] Reject: True
# Attempt 26/64: starting point [0.24961005 0.89595303]
# [0.34180614 0.82437649] Reject: True
# Attempt 27/64: starting point [0.4957546  0.46322266]
# [0.3418121  0.34181115] Reject: True
# Attempt 28/64: starting point [0.61632603 0.64689387]
# [0.82437298 0.82437623] Reject: True
# Attempt 29/64: starting point [0.71331271 0.31258379]
# [0.8243722 0.3418091] Reject: True
# Attempt 30/64: starting point [0.33480682 0.5118776 ]
# [0.34181229 0.34180987] Reject: True
# Attempt 31/64: starting point [0.08096804 0.0654682 ]
# [0.03455083 0.03455081] Reject: False
# Attempt 32/64: starting point [0.9671038  0.76485555]
# [0.82437651 0.82437567] Reject: True
# Attempt 33/64: starting point [0.94053318 0.36192981]
# [0.82437655 0.34180949] Reject: True
# Attempt 34/64: starting point [0.07776686 0.5611645 ]
# [0.03455192 0.34181026] Reject: True
# Attempt 35/64: starting point [0.32384034 0.11084873]
# [0.34181085 0.03455226] Reject: True
# Attempt 36/64: starting point [0.69448068 0.8102952 ]
# [0.82437242 0.82437492] Reject: True
# Attempt 37/64: starting point [0.60384178 0.23022712]
# [0.82437515 0.34181231] Reject: True
# Attempt 38/64: starting point [0.47551065 0.91405097]
# [0.34181222 0.82437583] Reject: True
# Attempt 39/64: starting point [0.2215064  0.47741422]
# [0.34180666 0.34180956] Reject: True
# Attempt 40/64: starting point [0.85783266 0.66102249]
# [0.82436578 0.82437703] Reject: True
# Attempt 41/64: starting point [0.78974951 0.01928491]
# [0.82437229 0.03454965] Reject: True
# Attempt 42/64: starting point [0.16020638 0.8432741 ]
# [0.03454837 0.82436674] Reject: True
# Attempt 43/64: starting point [0.4064482 0.2662373]
# [0.34181097 0.34180682] Reject: True
# Attempt 44/64: starting point [0.54349817 0.59044195]
# [0.34181232 0.82437629] Reject: True
# Attempt 45/64: starting point [0.62693129 0.38562963]
# [0.82437618 0.34180709] Reject: True
# Attempt 46/64: starting point [0.26295272 0.69420691]
# [0.34180717 0.82437128] Reject: True
# Attempt 47/64: starting point [0.00926844 0.13475634]
# [0.0345532 0.0345517] Reject: True
# Attempt 48/64: starting point [0.88063273 0.94312195]
# [0.82437562 0.82437651] Reject: True
# Attempt 49/64: starting point [0.91296674 0.1564047 ]
# [0.82437243 0.03455076] Reject: True
# Attempt 50/64: starting point [0.0413589  0.98054838]
# [0.03455083 0.82437656] Reject: True
# Attempt 51/64: starting point [0.29531547 0.40939099]
# [0.3418112  0.34181177] Reject: True
# Attempt 52/64: starting point [0.65905026 0.73344113]
# [0.8243724  0.82437418] Reject: True
# Attempt 53/64: starting point [0.51531457 0.30611276]
# [0.34180989 0.3418123 ] Reject: True
# Attempt 54/64: starting point [0.37801986 0.61453935]
# [0.34180539 0.8243749 ] Reject: True
# Attempt 55/64: starting point [0.13199406 0.05704668]
# [0.03454682 0.03454513] Reject: True
# Attempt 56/64: starting point [0.76129269 0.86556297]
# [0.82437233 0.82437487] Reject: True
# Attempt 57/64: starting point [0.82550037 0.43851607]
# [0.824375   0.34181231] Reject: True
# Attempt 58/64: starting point [0.1894179  0.63790144]
# [0.34180625 0.82437637] Reject: True
# Attempt 59/64: starting point [0.44314606 0.18953593]
# [0.3418113 0.3418103] Reject: True
# Attempt 60/64: starting point [0.57172073 0.88883173]
# [0.82437486 0.82437265] Reject: True
# Attempt 61/64: starting point [0.72266255 0.08627047]
# [0.82436708 0.0345546 ] Reject: True
# Attempt 62/64: starting point [0.35226671 0.76993983]
# [0.34181082 0.82436834] Reject: True
# Attempt 63/64: starting point [0.10598102 0.33914433]
# [0.03455467 0.34180978] Reject: True
# Attempt 64/64: starting point [0.96899208 0.5229071 ]
# [0.82437209 0.34181156] Reject: True
# minimum [0.824376   0.03455278]
# minimum [0.03455331 0.82437526]
# minimum [0.34181224 0.34181104]
# minimum [0.8243765  0.34181097]
# minimum [0.34181521 0.82436705]
# minimum [0.82437499 0.82437655]
# minimum [0.3418122  0.03455258]
# minimum [0.03455387 0.34181216]
# minimum [0.03455083 0.03455081]

# %%
# Save to CSV
results_df = save_critical_points_to_csv(minima, saddles, dimension=DIM, filename="critical_points_schwefel_torch.csv")
display(results_df)
# Out:
# Saved critical_points_schwefel_torch.csv
#          x1        x2   f_value     type  index
# 0  0.824376  0.034553 -0.063635  minimum      0
# 1  0.034553  0.824375 -0.063635  minimum      0
# 2  0.341812  0.341811  0.015296  minimum      0
# 3  0.824377  0.341811 -0.201843  minimum      0
# 4  0.341815  0.824367 -0.201843  minimum      0
# 5  0.824375  0.824377 -0.418983  minimum      0
# 6  0.341812  0.034553  0.153505  minimum      0
# 7  0.034554  0.341812  0.153505  minimum      0
# 8  0.034551  0.034551  0.291713  minimum      0

# %%
fig2 = plt.figure(figsize=(5,5), dpi=160)
fig2 = plot_results_with_paths(func=schwefel2D_numpy,  
                                critical_points_csv="./critical_points_schwefel_torch.csv",
                                saddle_to_minima_csv=None,      
                                bounds=(0, 1),
                                res=200,
                                fig=fig2
)
fig2.show()
fig2.savefig("plots/landscape_finder.png")  # Optional
# Out:
# /var/folders/87/h8fnyth55477f11hgmy38l4h0000gn/T/ipykernel_38298/309898632.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
