# %%
import sys
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')
import sys
print(sys.executable)

from connectivity.connectivity import trace_connectivity, extract_connection_indices, save_descent_paths
from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function, plot_full_connectivity_tree_style
from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss, schwefel2D_numpy
import matplotlib.pyplot as plt
# Out:
# /Users/rajmahadevwala/Documents/Documents/python-project/.venv/bin/python
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 9
#       6 print(sys.executable)
#       8 from connectivity.connectivity import trace_connectivity, extract_connection_indices, save_descent_paths
# ----> 9 from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function, plot_full_connectivity_tree_style
#      10 from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss, schwefel2D_numpy
#      11 import matplotlib.pyplot as plt
#
# File ~/Documents/Documents/python-project/Hiwi task/landscape-descriptors/test_schwefel/2d/../../connectivity/plot_results.py:5
#       3 from matplotlib import cm
#       4 from matplotlib.ticker import MaxNLocator
# ----> 5 from graph_tool.all import Graph, arf_layout, graph_draw
#       7 import pandas as pd
#       9 # Plot font Settings
#
# ModuleNotFoundError: No module named 'graph_tool'
