# %%
import sys
MODULEPATH="../../"
sys.path.append(MODULEPATH)
sys.path.append('../')
from connectivity.plot_results import plot_results_with_paths, plot_saddle_tree_with_function, plot_full_connectivity_tree_style

from critical_points.torch_critical_point_finder import find_critical_points_torch, save_critical_points_to_csv
from test_schwefel.schwefel_function_nnmodule import Schwefel2D, schwefel_loss, schwefel2D_numpy 

import matplotlib.pyplot as plt
import pandas as pd

# %%
model_builder = lambda p: Schwefel2D(*p)

# %%
# Set parameters
BOUNDS = {'x1': (0.0, 1.0), 'x2': (0.0, 1.0)}
DIM = 2
ATTEMPTS = 8
MIN_DISTANCE = 0.01

# %%
try:
    resume_df = pd.read_csv("critical_points_schwefel_torch.csv", index_col=0)
    display(resume_df)
except FileNotFoundError:
    resume_df = None

# %%
minima, maxima, saddles = find_critical_points_torch(
    model_builder=model_builder,
    minima_only=True,
    loss_func=schwefel_loss,
    input = [],             # placeholder model input for compatibility (Schwefel model has no model input)
    bounds=BOUNDS,
    dimension=DIM,
    num_attempts=ATTEMPTS,
    min_distance=MIN_DISTANCE,
    device="cpu",
    lr=5e-2,
    max_iter=5_000,
    resume_df=resume_df,  # 👈 here!
    seed=1101
)
# Out:
# __________________________________________________________________________________________
# Attempt 1/8:
# Starting point: [0.25317813 0.88321528]
# Arrival point: [0.34180915 0.82437793]
# check grad: tensor([-1.5548e-05,  1.4999e-04])
# tensor(0.0002)
# Converged to critical point with ||grad||=1.51e-04 < 1e-05
# New minimum found at [0.34180915 0.82437793] with value -0.201843
# Type: minimum
#
# __________________________________________________________________________________________
# Attempt 2/8:
# Starting point: [0.76250551 0.35659261]
# Arrival point: [0.82437273 0.34181001]
# check grad: tensor([-1.1582e-04,  2.8709e-05])
# tensor(0.0001)
# Converged to critical point with ||grad||=1.19e-04 < 1e-05
# New minimum found at [0.82437273 0.34181001] with value -0.201843
# Type: minimum
#
# __________________________________________________________________________________________
# Attempt 3/8:
# Starting point: [0.65636731 0.73049768]
# Arrival point: [0.82437494 0.82437722]
# check grad: tensor([-2.6564e-06,  1.1389e-04])
# tensor(0.0001)
# Converged to critical point with ||grad||=1.14e-04 < 1e-05
# New minimum found at [0.82437494 0.82437722] with value -0.418983
# Type: minimum
#
# __________________________________________________________________________________________
# Attempt 4/8:
# Starting point: [0.17145488 0.00906608]
# Out of bounds at 0 iterations.
# Arrival point: [ 0.34181158 -0.09946617]
# check grad: tensor([0.0001, 0.0002])
# tensor(0.0002)
# Converged to critical point with ||grad||=2.16e-04 < 1e-05
# Point [ 0.34181158 -0.09946617] is out of bounds [[0. 1.]
#  [0. 1.]]. Rejecting.
#
# __________________________________________________________________________________________
# Attempt 5/8:
# Starting point: [0.07226059 0.52750919]
# Out of bounds at 0 iterations.
# Arrival point: [-0.09946702  0.34181094]
# check grad: tensor([1.1660e-04, 7.6679e-05])
# tensor(0.0001)
# Converged to critical point with ||grad||=1.40e-04 < 1e-05
# Point [-0.09946702  0.34181094] is out of bounds [[0. 1.]
#  [0. 1.]]. Rejecting.
#
# __________________________________________________________________________________________
# Attempt 6/8:
# Starting point: [0.56879307 0.2435468 ]
# Arrival point: [0.82437714 0.34181041]
# check grad: tensor([1.0964e-04, 4.9696e-05])
# tensor(0.0001)
# Converged to critical point with ||grad||=1.20e-04 < 1e-05
# Point [0.82437714 0.34181041] is too close to existing minimum at [0.82437273 0.34181001] (distance 0.000004 < 0.01)
# Minimum at [0.82437273 0.34181001] has now been found 2 times.
# Point [0.82437714 0.34181041] is too close to existing minimum. Rejecting.
#
# __________________________________________________________________________________________
# Attempt 7/8:
# Starting point: [0.97913096 0.86745211]
# Arrival point: [0.82437539 0.82437163]
# check grad: tensor([ 2.0116e-05, -1.7200e-04])
# tensor(0.0002)
# Converged to critical point with ||grad||=1.73e-04 < 1e-05
# Point [0.82437539 0.82437163] is too close to existing minimum at [0.82437494 0.82437722] (distance 0.000006 < 0.01)
# Minimum at [0.82437494 0.82437722] has now been found 2 times.
# Point [0.82437539 0.82437163] is too close to existing minimum. Rejecting.
#
# __________________________________________________________________________________________
# Attempt 8/8:
# Starting point: [0.47380949 0.40335975]
# Arrival point: [0.34180902 0.3418065 ]
# check grad: tensor([-2.2198e-05, -1.5221e-04])
# tensor(0.0002)
# Converged to critical point with ||grad||=1.54e-04 < 1e-05
# New minimum found at [0.34180902 0.3418065 ] with value 0.015296
# Type: minimum
#
# === Basin Stats ===
# Total new distinct minima found: 4
# Total converged attempts (including duplicates): [1, 2, 2, 1]
# Converged to existing basin (duplicates): 6
# Convergence count per minimum:
# Min at [0.34180915 0.82437793] was hit 1 times
# Total converged attempts: 6
# Min at [0.82437273 0.34181001] was hit 2 times
# Total converged attempts: 6
# Min at [0.82437494 0.82437722] was hit 2 times
# Total converged attempts: 6
# Min at [0.34180902 0.3418065 ] was hit 1 times
# Total converged attempts: 6
# Saved basin counts to: ./basin_counts.csv

# %%
# Save to CSV
results_df = save_critical_points_to_csv(minima, maxima, saddles, dimension=DIM, filename="critical_points_schwefel_torch.csv")

results_df = pd.concat((resume_df,results_df), ignore_index=True)

display(results_df)
# Out:
# Saved critical_points_schwefel_torch.csv
# Empty DataFrame
# Columns: []
# Index: []
